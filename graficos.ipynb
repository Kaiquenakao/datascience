# %%
import matplotlib.pyplot as plt

# %%
years = [i for i in range(1950, 2020, 10)]
gdp = [300.2, 543.3, 1075.9, 2862.5, 5979.6, 10289.7, 14958.3]

# %%
plt.plot(years, gdp, 'go-')
plt.title('Nominal GPD')
plt.ylabel("Billions of $")
# Out:
# Text(0, 0.5, 'Billions of $')

# %% [markdown]
# ## Gráficos de Barras

# %%
movies = ["Annie Hall", "Ben-Hur", "Casa Blanca", "Gandhi", "West Side Story"]
num_oscars = [5, 11, 3, 8, 10]

# %%
plt.bar(range(len(movies)), num_oscars)

plt.title("My Favorite Movies")
plt.ylabel("# of Academy Awards")

plt.xticks(range(len(movies)), movies);

# %%
from collections import Counter

# %%
grades = [83, 95, 91, 87, 70, 0, 85, 82, 100, 67, 73, 77, 0]

plt.hist(grades, bins=10, edgecolor='black')

plt.axis([-5, 105, 0, 5])

plt.xticks([10 * i for i in range(11)])

plt.xlabel("Notas")
plt.ylabel("N de alunos")
plt.title("Distribuição das Notas da 1 Avaliação")
# Out:
# Text(0.5, 1.0, 'Distribuição das Notas da 1 Avaliação')

# %%
mentions = [500, 505]
years = [2017, 2018]

plt.bar(years, mentions, 0.8)

plt.xticks(years)
plt.ylabel("N de vezes em que ouvi alguém dizer 'data Sciente'")

plt.ticklabel_format(useOffset=False)

plt.axis([2016.5, 2018.5, 499, 506])
plt.title("Observe Esse Aumento 'Imenso'!")
# Out:
# Text(0.5, 1.0, "Observe Esse Aumento 'Imenso'!")

# %% [markdown]
# ## Gráficos de Linhas

# %%
variance = [1, 2, 4, 8, 16, 32, 64, 128, 256]
bias_squared = [256, 128, 64, 32, 16, 8, 4, 2, 1]
total_error = [x + y for x, y in zip(variance, bias_squared)]
xs = [i for i, _ in enumerate(variance)]


plt.plot(xs, variance, 'g-', label="variance")
plt.plot(xs, bias_squared, 'r-.', label="bias^2")

plt.plot(xs, total_error, "b:", label="total error")

plt.legend(loc=9)
plt.xlabel("model complexity")
plt.xticks([])
plt.title("O Dilema Viés-Variância")
# Out:
# Text(0.5, 1.0, 'O Dilema Viés-Variância')

# %% [markdown]
# ## Gráficos de Dispersão

# %%
friends = [70, 65, 72, 63, 71, 64, 60, 64, 67]
minutes = [175, 170, 205, 120, 220, 130, 105, 145, 190]
labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i']

plt.scatter(friends, minutes)

for label, friend_count, minute_count in zip(labels, friends, minutes):
    plt.annotate(label,
                xy=(friend_count, minute_count),
                xytext=(5, -5),
                 textcoords='offset points'
                )
    
plt.title("Minutos Diários x Número de Amigos")
plt.xlabel("n de amigos")
plt.ylabel("minutos diários dedicados ao site")
# Out:
# Text(0, 0.5, 'minutos diários dedicados ao site')
